# %% [markdown]
# Technological Institute of the Philippines | Quezon City - Computer Engineering
# --- | ---
# Course Code: | CPE 019
# Code Title: | Emerging Technologies in CpE 2
# 1st Semester | AY 2023-2024
# <hr> | <hr>
# <u>**Hands-on Activity 4.1** | **Advanced Data Analytics and Machine Learning  **
# **Name** | Abad, Julia Marie Iberet B.
# **Section** | CPE32S3
# **Date Performed**: | February 21, 2024
# **Date Submitted**: | February 23, 2024
# **Instructor**: | Engr. Roman Richard

# %% [markdown]
# #PART 1
# ##Part 1: Import the Libraries and Data

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
trainFrame = pd.read_csv('/content/titanic_train.csv')
trainFrame
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
testFrame = pd.read_csv('/content/titanic_test.csv')
testFrame
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %% [markdown]
# ##Part 2: Plot the Data

# %%
import matplotlib.pyplot as plt

#Plotting Fare vs. Age
plt.figure(figsize=(10, 6))
plt.scatter(trainFrame['Age'], trainFrame['Fare'])
plt.title('Scatter Plot of Fare vs. Age')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.grid(True)
plt.show()

# %%
#Plotting Fare vs. Pclass
plt.figure(figsize=(10, 6))
plt.scatter(trainFrame['Pclass'], trainFrame['Fare'])
plt.title('Scatter Plot of Fare vs. Pclass')
plt.xlabel('Pclass')
plt.ylabel('Fare')
plt.grid(True)
plt.show()

# %% [markdown]
# ##Part 3: Perform Simple Linear Regression on the SURVIVAL feature column

# %%
#Part 3: Perform Simple Linear Regression on the SURVIVAL feature column
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')

X_train_imputed = imputer.fit_transform(X_train)
X_test_imputed = imputer.transform(X_test)

model.fit(X_train_imputed, y_train)

y_pred = model.predict(X_test_imputed)

mse = mean_squared_error(y_test, y_pred)
r_squared = r2_score(y_test, y_pred)
print("Mean Squared Error:", mse)
print("R-squared:", r_squared)
# Out:
# Mean Squared Error: 0.1880398114088627
# R-squared: 0.2245838356047143

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import linear_model

# %%
df = pd.read_csv('/content/titanic_train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
model=linear_model.LinearRegression()

# %%
cleaned_df = df.dropna(subset=['Age'])

# %%
model.fit(cleaned_df[["Age"]], cleaned_df[["Survived"]])
# Out:
# LinearRegression()

# %%
model.score(cleaned_df[["Age"]],cleaned_df[["Survived"]])
# Out:
# 0.005963097446925136

# %%
model.coef_
# Out:
# array([[-0.00261254]])

# %%
model.intercept_
# Out:
# array([0.48375263])

# %%
y=-0.00261254*0.48375263

# %%
y
# Out:
# -0.0012638230959802

# %% [markdown]
# #PART 2
# ###Part 1: Create a Decision Tree Classifier
# In this part of the lab, you will create a decision tree classifier that will learn from a labelled dataset. <br>
#
#
# The dataset contains the names and demographic details for each passenger. In addition, details of the
# passengers' trip are included. From this data, we can be build a decision tree that illustrates the factors that
# contributed to survivability, or lack of it, for the voyage.<br>
#
#
# The datasets contain the following variables

# %% [markdown]
# ###Question
# With the data above, what kinds of questions can we ask about the factors that contributed to passengers surviving or perishing in the Titanic disaster?
#
# - Did gender play a role in survival rates?
# - What certain age groups of passengers are more likely to survive?
# - Did passenger class affect survival rates?
# - Were individuals travelling with family members more likely to survive?
# - Did the cabin numbers have correlation to the survival rates?

# %%
#Step 1: Create the dataframe
#Import pandas and the csv file
import pandas as pd

titanic_test = '\content\titanic_test.csv'
titanic_train = '\content\titanic _train.csv'

testFrame = pd.read_csv ('titanic_test.csv')
trainFrame = pd.read_csv ('titanic_train.csv')

# %%
#Verify the import and take a look at the data
#verify the contents of the training dataframe using the pandas info() method.
testFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
trainFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#view the first few rows of the data
testFrame.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
trainFrame.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Step 2: Prepare the Data for the Decision Tree Model.
trainFrame['Sex'] = trainFrame['Sex'].apply(lambda toLabel: 0 if toLabel == 'male'else 1)

# %%
#Verify that the sex variable has been changed.
trainFrame.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
#Address Missing Values in the Dataset
trainFrame['Age'].fillna(trainFrame['Age'].mean(), inplace = True)

# %%
#Verify that the values have been replaced
trainFrame
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.000000      1
# 2                               Heikkinen, Miss. Laina    1  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.000000      1
# 4                             Allen, Mr. William Henry    0  35.000000      0
# ...

# %%
#What is the value that was used to replace the missing ages?

print(trainFrame['Age'].mean())
# Out:
# 29.69911764705882

# %%
#Step 3: Train and Score the Decision Tree Model.
#Create an array object with the variable that will be the target for the model.
y_target = trainFrame["Survived"].values

# %%
#Create an array of the values that will be the input for the model.
columns = ["Fare", "Pclass", "Sex", "SibSp"]
X_input = trainFrame[columns].values

# %%
#Create the learned model.
from sklearn import tree

clf_train = tree.DecisionTreeClassifier(criterion = "entropy", max_depth=3)
clf_train = clf_train.fit(X_input, y_target)

# %%
#Evaluate the model
clf_train.score(X_input, y_target)
# Out:
# 0.8103254769921436

# %%
#Step 6: Visualize the Tree
#Create the intermediate file output
from sklearn.tree import export_graphviz
with open("titanic.dot", 'w') as f:
  f = tree.export_graphviz(clf_train, out_file=f, feature_names=columns)

# %%
#Install Graphviz
# !pip install graphviz

# %%
#Convert the intermediate file to a graphic
# !dot -Tpng titanic.dot -o titanic.png

# %%
#Display the image
from IPython.display import Image

Image("titanic.png")

# %% [markdown]
# ##Interpret the tree
# What describes the group that had the most deaths by number? Which group had the most survivors?
# - The Male (0) group with Fare <= 26.269 and Age <= 13.5 had the most number of deathes. And the Female (1) group had the most survivors.

# %% [markdown]
# ##Part 2: Apply the Decision Tree Model
# In this part of the lab, we will use the results of the learned decision tree model to label an unlabelled dataset of
# Titanic passengers. The decision tree will evaluate the features of each observation and label the observation as
# survived (label = 1) or died (label = 0).

# %%
#Step 1: Import and Prepare the Data
testing = pd.read_csv("/content/titanic_test.csv")

# %%
#How many records are in the data set?
# Number of records in the dataset
num_records = len(testing)
print("Number of records in the dataset:", num_records)
# Out:
# Number of records in the dataset: 418

# %%
#Which important variables(s) are missing values and how many are missing?
missing_values = testing.isnull().sum()
print("\nMissing values in important variables:")
print(missing_values)
# Out:
# Missing values in important variables:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
#Use a lambda expression to replace the "male" and "female" values with 0 for male and 1 for female..
testing['Sex'] = testing['Sex'].apply(lambda toLabel: 0 if toLabel == 'male' else 1)

# %%
testing
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
#Replace the missing age values with the mean of the ages
testing["Age"].fillna(testing["Age"].mean(), inplace = True)

# %%
#Verify that the values have been replaced.
testing.info()
testing.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    int64
#  4   Age          418 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         418 non-null    float64
#  9   Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 32.8+ KB
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    0
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    1
# 2          894       2                     Myles, Mr. Thomas Francis    0
# ...

# %%
#Step 2: Label the testing dataset
#Create the array of input variables from the testing data set.
columns = ["Fare", "Pclass", "Sex", "Age"]
X_input = testing[list(columns)].values

# %%
testing['Sex'] = testing['Sex'].apply(lambda toLabel: 0 if toLabel == 'male'else 1)

# %%
#Apply the model to the testing data set
target_labels = clf_train.predict(X_input)
target_labels = pd.DataFrame({'Est_Survival': target_labels, 'Name': testing['Name']})

target_labels.head()
# Out:
#    Est_Survival                                          Name
# 0             1                              Kelly, Mr. James
# 1             1              Wilkes, Mrs. James (Ellen Needs)
# 2             1                     Myles, Mr. Thomas Francis
# 3             1                              Wirz, Mr. Albert
# 4             1  Hirvonen, Mrs. Alexander (Helga E Lindqvist)

# %%
#Evaluate the accuracy of the estimated labels
import numpy as np

all_data = pd.read_csv("/content/titanic_all.csv")
testing_results = pd.merge(target_labels, all_data[['Name','Survived']], on=['Name'])
acc = np.sum(testing_results['Est_Survival'] == testing_results['Survived']) / float(len(testing_results))

print("Accuracy of the learned model:", acc)
# Out:
# Accuracy of the learned model: 0.4005037783375315

# %% [markdown]
# ####Part 3: Evaluate the Decision Tree Model
# The sklearn library includes a module that can be used to evaluate the accurracy of the decision tree model.
# The train_test_split() method will divide the observations in whole data set into two randomly selected
# arrays of observations that makeup the testing and training datasets. After fitting the model to the training data,
# the trained model can be scored and the prediction accurracy compared for both the training and test datasets. It
# is desirable for the two scores to be close, but the accuracy for the test dataset is normally lower that for the
# training data set.

# %%
#Step 1: Import the data
import pandas as pd

all_data = pd.read_csv("/content/titanic_all.csv", usecols = ['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Fare'])
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1308 entries, 0 to 1307
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  1308 non-null   int64
#  1   Pclass    1308 non-null   int64
#  2   Sex       1308 non-null   object
#  3   Age       1045 non-null   float64
#  4   SibSp     1308 non-null   int64
#  5   Fare      1308 non-null   float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 61.4+ KB

# %%
#How many records are in the data set?
num_records = all_data.shape[0]

print("Number of records in the dataset:", num_records)
# Out:
# Number of records in the dataset: 1308

# %%
#Which important variables(s) are missing values and how many are missing?
missing_values = all_data.isnull().sum()
print("\nMissing values in important variables:")
print(missing_values)
# Out:
# Missing values in important variables:
# Survived      0
# Pclass        0
# Sex           0
# Age         263
# SibSp         0
# Fare          0
# dtype: int64

# %%
#Step 2: Prepare the data.
#Remove the "male" and "female" strings and replace them with 0 and 1 respectively
all_data['Sex'] = all_data['Sex'].apply(lambda toLabel: 0 if toLabel == 'male'else 1)

# %%
#Replace the missing age values with the mean of the age of all members of the data set.
all_data["Age"].fillna(all_data["Age"].mean(), inplace=True)
all_data.head()
# Out:
#    Survived  Pclass  Sex      Age  SibSp      Fare
# 0         1       1    1  29.0000      0  211.3375
# 1         1       1    0   0.9167      1  151.5500
# 2         0       1    1   2.0000      1  151.5500
# 3         0       1    0  30.0000      1  151.5500
# 4         0       1    1  25.0000      1  151.5500

# %%
#Step 2: Create the input and output variables for the training and testing data.
#Designate the input variables and output variables and generate the arrays.
from sklearn.model_selection import train_test_split

X = all_data[list(columns)].values
y = all_data["Survived"].values

X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=0.40, random_state=0)

# %%
#Train the model and fit it to the testing data
clf_train = tree.DecisionTreeClassifier(criterion="entropy", max_depth=3)

clf_train = clf_train.fit(X_train, y_train)

# %%
#Compare models by scoring each.
train_score = str(clf_train.score(X_train,y_train))
test_score = str(clf_train.score(X_test,y_test))

print('Training score = '+ train_score+' Testing score = '+test_score)
# Out:
# Training score = 0.8125 Testing score = 0.8034351145038168

# %% [markdown]
# ##Part 4 For Further Study (optional)
# If you have the time and are interested, you could try the following and see how the decision tree is affected.

# %% [markdown]
# 1. Remove observations with missing Age values.
# Using a mean to replace missing age values may affect the accuracy of the model. One approach to this might
# be to remove all observations with missing age values. Although this will decrease the size of the training
# dataset, it could improve accuracy.

# %%
all_data.dropna(subset=['Age'], inplace=True)

# %% [markdown]
# 2.Remove the input variables.
# Another issue with this type of analysis is the identification of which input variables, or features, are essential to
# the accuracy of the classifier. One way to do this is to try running the classifier with different sets of input
# variables by editing the list of variables that is used to fit the model.

# %%
all_data.drop(columns=['Fare', 'SibSp'], inplace=True)
